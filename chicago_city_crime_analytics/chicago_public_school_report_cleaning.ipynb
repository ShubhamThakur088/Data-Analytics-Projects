# %%
import pandas as pd

# %%
df = pd.read_csv('D:/CSV-Files/Chicago_Public_Schools_-_Progress_Report_Cards_(2011-2012)_20260122.csv')
df.head()
# Out:
#    School ID                                     Name of School  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
#
#   Elementary, Middle, or High School          Street Address     City State  \
# 0                                 ES        615 W Kemper Pl   Chicago    IL
# 1                                 ES  7511 S South Shore Dr   Chicago    IL
# 2                                 ES     8010 S Kostner Ave   Chicago    IL
# 3                                 ES     4619 S Wolcott Ave   Chicago    IL
# 4                                 HS        3630 S Wells St   Chicago    IL
#
#    ZIP Code    Phone Number  \
# 0     60614  (773) 534-5720
# 1     60649  (773) 535-6650
# 2     60652  (773) 535-2280
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 566 entries, 0 to 565
# Data columns (total 78 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   School ID                                          566 non-null    int64
#  1   Name of School                                     566 non-null    str
#  2   Elementary, Middle, or High School                 566 non-null    str
#  3   Street Address                                     566 non-null    str
#  4   City                                               566 non-null    str
#  5   State                                              566 non-null    str
#  6   ZIP Code                                           566 non-null    int64
#  7   Phone Number                                       566 non-null    str
#  8   Link                                               565 non-null    str
# ...

# %%
df.duplicated().sum()
pd.set_option('display.max_rows', None)

# %%
df.isnull().sum()
# Out:
# School ID                                             0
# Name of School                                        0
# Elementary, Middle, or High School                    0
# Street Address                                        0
# City                                                  0
# State                                                 0
# ZIP Code                                              0
# Phone Number                                          0
# Link                                                  1
# Network Manager                                       0
# Collaborative Name                                    0
# Adequate Yearly Progress Made?                        0
# Track Schedule                                        0
# CPS Performance Policy Status                         0
# CPS Performance Policy Level                          0
# Healthy Schools Certified?                            0
# Safety Icon                                           0
# ...

# %%
df.columns
# Out:
# Index(['School ID', 'Name of School', 'Elementary, Middle, or High School',
#        'Street Address', 'City', 'State', 'ZIP Code', 'Phone Number', 'Link ',
#        'Network Manager', 'Collaborative Name',
#        'Adequate Yearly Progress Made? ', 'Track Schedule',
#        'CPS Performance Policy Status', 'CPS Performance Policy Level',
#        'Healthy Schools Certified?', 'Safety Icon ', 'Safety Score',
#        'Family Involvement Icon', 'Family Involvement Score',
#        'Environment Icon ', 'Environment Score', 'Instruction Icon ',
#        'Instruction Score', 'Leaders Icon ', 'Leaders Score ',
#        'Teachers Icon ', 'Teachers Score', 'Parent Engagement Icon ',
#        'Parent Engagement Score', 'Parent Environment Icon',
#        'Parent Environment Score', 'Average Student Attendance',
#        'Rate of Misconducts (per 100 students) ', 'Average Teacher Attendance',
#        'Individualized Education Program Compliance Rate ', 'Pk-2 Literacy %',
# ...

# %%
avg_student_attendance = df['Average Student Attendance']
print(avg_student_attendance)
# Out:
# 0      96.00%
# 1      95.60%
# 2      95.70%
# 3      95.50%
# 4      93.30%
#         ...
# 561    91.20%
# 562    80.00%
# 563    95.20%
# 564    93.90%
# 565    91.60%
# Name: Average Student Attendance, Length: 566, dtype: str

# %%
cleaned_student_attendance_data = df['Average Student Attendance'].str.replace('%','')
print(cleaned_student_attendance_data)
df['Average Student Attendance'] = df['Average Student Attendance'].str.replace('%','')
# Out:
# 0      96.00
# 1      95.60
# 2      95.70
# 3      95.50
# 4      93.30
#        ...
# 561    91.20
# 562    80.00
# 563    95.20
# 564    93.90
# 565    91.60
# Name: Average Student Attendance, Length: 566, dtype: str

# %%
cleaned_teacher_attendance_data = df['Average Teacher Attendance'].str.replace('%', '')
print(cleaned_teacher_attendance_data)
df['Average Teacher Attendance'] = df['Average Teacher Attendance'].str.replace('%','')
# Out:
# 0      96.40
# 1      95.30
# 2      94.70
# 3      95.80
# 4      96.90
#        ...
# 561    95.90
# 562    95.60
# 563    96.40
# 564    94.30
# 565    96.00
# Name: Average Teacher Attendance, Length: 566, dtype: str

# %%
df.to_csv('D:/CSV-Files/Chicago_Public_Schools_-_Progress_Report_Cards_(2011-2012)_20260122.csv', index = False)

# %%
chicago_public_schools_df = pd.read_csv('D:/CSV-Files/Chicago_Public_Schools_-_Progress_Report_Cards_(2011-2012)_20260122.csv')

for column, column_values in chicago_public_schools_df.items():
    if column == 'Average Teacher Attendance':
        print(column_values)
# Out:
# 0      96.4
# 1      95.3
# 2      94.7
# 3      95.8
# 4      96.9
# 5      96.9
# 6      96.2
# 7      95.0
# 8      96.9
# 9      95.9
# 10     95.9
# 11     95.0
# 12     97.4
# 13     96.0
# 14     94.7
# 15     94.2
# 16     95.2
# 17     95.0
# 18     95.1
# 19     96.6
# 20     95.4
# 21     96.0
# 22     95.5
# 23     95.6
# 24     94.4
# 25     96.1
# 26     95.4
# 27     96.5
# 28     95.6
# 29     94.9
# 30     96.0
# 31     95.8
# 32     95.2
# 33     95.1
# 34     95.6
# 35     96.1
# 36     93.4
# 37     95.3
# 38     97.1
# 39     95.0
# 40      0.0
# 41     94.1
# 42     95.2
# 43     96.4
# 44     95.5
# 45     96.8
# 46     95.8
# 47     93.9
# 48     96.6
# 49     96.3
# 50     93.9
# 51     94.8
# 52     94.8
# 53     95.4
# 54     95.0
# 55     95.9
# 56     95.6
# 57     96.9
# 58     94.9
# 59     96.9
# 60     96.0
# 61     96.3
# 62     94.3
# 63     95.6
# 64     94.7
# 65     96.1
# 66     94.4
# 67     94.7
# 68     95.6
# 69     95.2
# 70     93.4
# ...

# %%
chicago_public_schools_df = pd.read_csv('D:/CSV-Files/Chicago_Public_Schools_-_Progress_Report_Cards_(2011-2012)_20260122.csv', index_col = False)

for column, column_values in chicago_public_schools_df.items():
    if column == 'Average Student Attendance':
        print(column_values)
# Out:
# 0      96.0
# 1      95.6
# 2      95.7
# 3      95.5
# 4      93.3
# 5      97.0
# 6      96.3
# 7      94.7
# 8      92.7
# 9      96.4
# 10     96.3
# 11     92.5
# 12     95.3
# 13     92.5
# 14     94.9
# 15     90.1
# 16     94.6
# 17     95.6
# 18     80.3
# 19     96.9
# 20     96.3
# 21     94.3
# 22     91.4
# 23     95.4
# 24     94.6
# 25     97.4
# 26     91.8
# 27     97.5
# 28     94.6
# 29     90.5
# 30     95.5
# 31     94.2
# 32     92.8
# 33     90.8
# 34     94.8
# 35     96.1
# 36     87.9
# 37     92.1
# 38     95.5
# 39     96.5
# 40     76.0
# 41     90.5
# 42     70.1
# 43     92.1
# 44     60.9
# 45     95.3
# 46     83.7
# 47     91.3
# 48     95.5
# 49     93.0
# 50     88.9
# 51     94.7
# 52     80.2
# 53     94.2
# 54     90.6
# 55     96.3
# 56     92.3
# 57     95.5
# 58     94.9
# 59     96.5
# 60     81.2
# 61     95.8
# 62     91.7
# 63     94.8
# 64     91.9
# 65     95.1
# 66     86.0
# 67     94.4
# 68     95.7
# 69     95.3
# 70     93.4
# ...

# %%
import matplotlib

chicago_public_schools_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 566 entries, 0 to 565
# Data columns (total 78 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   School ID                                          566 non-null    int64
#  1   Name of School                                     566 non-null    str
#  2   Elementary, Middle, or High School                 566 non-null    str
#  3   Street Address                                     566 non-null    str
#  4   City                                               566 non-null    str
#  5   State                                              566 non-null    str
#  6   ZIP Code                                           566 non-null    int64
#  7   Phone Number                                       566 non-null    str
#  8   Link                                               565 non-null    str
# ...

# %%
print(chicago_public_schools_df)
# Out:
#      School ID                                     Name of School  \
# 0       610038                  Abraham Lincoln Elementary School
# 1       610281  Adam Clayton Powell Paideia Community Academy ...
# 2       610185                Adlai E Stevenson Elementary School
# 3       609993                    Agustin Lara Elementary Academy
# 4       610513                      Air Force Academy High School
# 5       610212                  Albany Park Multicultural Academy
# 6       609720                Albert G Lane Technical High School
# 7       610342            Albert R Sabin Elementary Magnet School
# 8       610524              Alcott High School for the Humanities
# 9       610209                 Alessandro Volta Elementary School
# 10      609799            Alexander Graham Bell Elementary School
# 11      609947                 Alexander Graham Elementary School
# 12      609963               Alexander Hamilton Elementary School
# ...

# %%
print(chicago_public_schools_df.columns)
# Out:
# Index(['School ID', 'Name of School', 'Elementary, Middle, or High School',
#        'Street Address', 'City', 'State', 'ZIP Code', 'Phone Number', 'Link ',
#        'Network Manager', 'Collaborative Name',
#        'Adequate Yearly Progress Made? ', 'Track Schedule',
#        'CPS Performance Policy Status', 'CPS Performance Policy Level',
#        'Healthy Schools Certified?', 'Safety Icon ', 'Safety Score',
#        'Family Involvement Icon', 'Family Involvement Score',
#        'Environment Icon ', 'Environment Score', 'Instruction Icon ',
#        'Instruction Score', 'Leaders Icon ', 'Leaders Score ',
#        'Teachers Icon ', 'Teachers Score', 'Parent Engagement Icon ',
#        'Parent Engagement Score', 'Parent Environment Icon',
#        'Parent Environment Score', 'Average Student Attendance',
#        'Rate of Misconducts (per 100 students) ', 'Average Teacher Attendance',
#        'Individualized Education Program Compliance Rate ', 'Pk-2 Literacy %',
# ...

# %%
college_enrollments = chicago_public_schools_df['College Enrollment (number of students) ']
print(college_enrollments)
# Out:
# 0        813
# 1        521
# 2      1,324
# 3        556
# 4        302
# 5        266
# 6      4,368
# 7        620
# 8        232
# 9      1,023
# 10       998
# 11       476
# 12       307
# 13       398
# 14       525
# 15       428
# 16       801
# 17       274
# 18       551
# 19       171
# 20       264
# 21       586
# 22       539
# 23       114
# 24       730
# 25       556
# 26       339
# 27       245
# 28       669
# 29       436
# 30       550
# 31       345
# 32       905
# 33       539
# 34       652
# 35       784
# 36       459
# 37       573
# 38       490
# 39       572
# 40       316
# 41       337
# 42       250
# 43       398
# 44       204
# 45       634
# 46     1,683
# 47       302
# 48       301
# 49       429
# 50       350
# 51       325
# 52       137
# 53       340
# 54       549
# 55       691
# 56       550
# 57       286
# 58       766
# 59       792
# 60     2,366
# 61       644
# 62       343
# 63       537
# 64       329
# 65       915
# ...
