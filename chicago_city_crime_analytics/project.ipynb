# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
print(pd.__version__)
# Out:
# 3.0.0

# %%
df = pd.read_csv('D:/CSV-Files/ChicagoCrimeData.csv');
df.shape
df.head()
# Out:
#          ID CASE_NUMBER        DATE                     BLOCK IUCR  \
# 0   3512276    HK587712  2004-08-28        047XX S KEDZIE AVE  890
# 1   3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE  820
# 2   8002131    HT233595  2011-04-04        043XX S WABASH AVE  820
# 3   7903289    HT133522  2010-12-30      083XX S KINGSTON AVE  840
# 4  10402076    HZ138551  2016-02-02           033XX W 66TH ST  820
#
#   PRIMARY_TYPE                    DESCRIPTION          LOCATION_DESCRIPTION  \
# 0        THEFT                  FROM BUILDING            SMALL RETAIL STORE
# 1        THEFT                 $500 AND UNDER                         OTHER
# 2        THEFT                 $500 AND UNDER  NURSING HOME/RETIREMENT HOME
# 3        THEFT  FINANCIAL ID THEFT: OVER $300                     RESIDENCE
# 4        THEFT                 $500 AND UNDER                         ALLEY
#
#    ARREST  DOMESTIC  ...  DISTRICT  WARD  COMMUNITY_AREA_NUMBER  FBICODE  \
# ...

# %%
df.describe()
# Out:
#                  ID         BEAT    DISTRICT        WARD  \
# count  5.330000e+02   533.000000  533.000000  490.000000
# mean   6.228301e+06  1187.037523   11.195122   22.608163
# std    3.027454e+06   660.592263    6.496631   13.080119
# min    2.114900e+04   111.000000    1.000000    1.000000
# 25%    3.420516e+06   711.000000    6.000000   12.000000
# 50%    6.231712e+06  1111.000000   10.000000   24.000000
# 75%    8.875058e+06  1634.000000   16.000000   32.000000
# max    1.127717e+07  2535.000000   25.000000   50.000000
#
#        COMMUNITY_AREA_NUMBER  X_COORDINATE  Y_COORDINATE        YEAR  \
# count             490.000000  5.290000e+02  5.290000e+02   533.00000
# mean               37.542857  1.162876e+06  1.886223e+06  2008.34334
# std                21.409514  1.650197e+04  3.009980e+04     4.94940
# min                 1.000000  1.100658e+06  1.814512e+06  2001.00000
# 25%                23.000000  1.151715e+06  1.860454e+06  2004.00000
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 533 entries, 0 to 532
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     533 non-null    int64
#  1   CASE_NUMBER            533 non-null    str
#  2   DATE                   533 non-null    str
#  3   BLOCK                  533 non-null    str
#  4   IUCR                   533 non-null    str
#  5   PRIMARY_TYPE           533 non-null    str
#  6   DESCRIPTION            533 non-null    str
#  7   LOCATION_DESCRIPTION   533 non-null    str
#  8   ARREST                 533 non-null    bool
#  9   DOMESTIC               533 non-null    bool
#  10  BEAT                   533 non-null    int64
#  11  DISTRICT               533 non-null    int64
#  12  WARD                   490 non-null    float64
#  13  COMMUNITY_AREA_NUMBER  490 non-null    float64
#  14  FBICODE                533 non-null    str
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# ID                        0
# CASE_NUMBER               0
# DATE                      0
# BLOCK                     0
# IUCR                      0
# PRIMARY_TYPE              0
# DESCRIPTION               0
# LOCATION_DESCRIPTION      0
# ARREST                    0
# DOMESTIC                  0
# BEAT                      0
# DISTRICT                  0
# WARD                     43
# COMMUNITY_AREA_NUMBER    43
# FBICODE                   0
# X_COORDINATE              4
# Y_COORDINATE              4
# YEAR                      0
# LATITUDE                  4
# LONGITUDE                 4
# LOCATION                  4
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                       0
# CASE_NUMBER              0
# DATE                     0
# BLOCK                    0
# IUCR                     0
# PRIMARY_TYPE             0
# DESCRIPTION              0
# LOCATION_DESCRIPTION     0
# ARREST                   0
# DOMESTIC                 0
# BEAT                     0
# DISTRICT                 0
# WARD                     0
# COMMUNITY_AREA_NUMBER    0
# FBICODE                  0
# X_COORDINATE             0
# Y_COORDINATE             0
# YEAR                     0
# LATITUDE                 0
# LONGITUDE                0
# LOCATION                 0
# dtype: int64

# %%
df.shape
# Out:
# (487, 21)

# %%
df['DATE'] = pd.to_datetime(df['DATE'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 487 entries, 0 to 531
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     487 non-null    int64
#  1   CASE_NUMBER            487 non-null    str
#  2   DATE                   487 non-null    datetime64[us]
#  3   BLOCK                  487 non-null    str
#  4   IUCR                   487 non-null    str
#  5   PRIMARY_TYPE           487 non-null    str
#  6   DESCRIPTION            487 non-null    str
#  7   LOCATION_DESCRIPTION   487 non-null    str
#  8   ARREST                 487 non-null    bool
#  9   DOMESTIC               487 non-null    bool
#  10  BEAT                   487 non-null    int64
#  11  DISTRICT               487 non-null    int64
#  12  WARD                   487 non-null    float64
#  13  COMMUNITY_AREA_NUMBER  487 non-null    float64
#  14  FBICODE                487 non-null    str
# ...

# %%
df.columns
# Out:
# Index(['ID', 'CASE_NUMBER', 'DATE', 'BLOCK', 'IUCR', 'PRIMARY_TYPE',
#        'DESCRIPTION', 'LOCATION_DESCRIPTION', 'ARREST', 'DOMESTIC', 'BEAT',
#        'DISTRICT', 'WARD', 'COMMUNITY_AREA_NUMBER', 'FBICODE', 'X_COORDINATE',
#        'Y_COORDINATE', 'YEAR', 'LATITUDE', 'LONGITUDE', 'LOCATION'],
#       dtype='str')
